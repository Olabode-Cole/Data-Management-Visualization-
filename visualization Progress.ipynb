# %%
import pandas as pd
import numpy as np
import csv
import os
import bokeh
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2d01e7f9-2a1b-47a3-a884-6ebcd0e63a72">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, ColorBar

# %%
nba = pd.read_csv(r"C:\users\olabo\Desktop\NBA2018.csv", index_col='YEAR')
nba.head()
# Out:
#                        TEAM  GP   W  L   WIN%   MIN    PTS   FGM   FGA   FG%  \
# YEAR
# 2018        Toronto Raptors  22  18  4  0.818  48.2  117.0  44.1  89.6  49.3
# 2018        Milwaukee Bucks  20  14  6  0.700  48.3  121.0  44.7  91.8  48.7
# 2018            LA Clippers  19  13  6  0.684  48.8  116.8  41.6  88.7  46.9
# 2018  Golden State Warriors  22  15  7  0.682  48.2  116.0  43.2  87.4  49.4
# 2018         Denver Nuggets  21  14  7  0.667  48.2  110.3  41.9  90.0  46.6
#
#       ...   DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD   +/-
# YEAR  ...
# 2018  ...   36.1  46.5  25.5  15.2  8.3  5.5   5.0  22.1  20.8   8.9
# 2018  ...   40.5  50.6  27.3  15.5  6.9  6.0   5.0  20.9  20.7  11.1
# 2018  ...   37.4  46.8  22.2  14.2  5.8  5.5   6.5  23.6  25.3   4.4
# 2018  ...   36.1  45.8  27.9  14.9  7.3  6.4   3.6  22.5  20.5   5.3
# 2018  ...   35.4  47.5  26.5  14.3  8.5  5.0   5.8  21.0  21.5   8.0
#
# [5 rows x 27 columns]

# %%
nba.loc[2018].PTS.head()
# Out:
# YEAR
# 2018    117.0
# 2018    121.0
# 2018    116.8
# 2018    116.0
# 2018    110.3
# Name: PTS, dtype: float64

# %%
p = figure(
    height=300, x_axis_type='log', y_range=(0, 20))
p.circle(x=nba.loc[2018].PTS, y=nba.loc[2018].W)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="cff68b83-c825-4da6-8b47-9735e40f4e00"></div>
# </div>

# %%
p.xaxis
# Out:
# [bokeh.models.axes.LogAxis(
#      id='594f52bc-7ee2-4a6f-ad10-4616256c68ec',
#      axis_label='',
#      axis_label_standoff=5,
#      axis_label_text_align='left',
#      axis_label_text_alpha={'value': 1.0},
#      axis_label_text_baseline='bottom',
#      axis_label_text_color={'value': '#444444'},
#      axis_label_text_font='helvetica',
#      axis_label_text_font_size={'value': '10pt'},
#      axis_label_text_font_style='italic',
#      axis_label_text_line_height=1.2,
#      axis_line_alpha={'value': 1.0},
#      axis_line_cap='butt',
#      axis_line_color={'value': 'black'},
#      axis_line_dash=[],
#      axis_line_dash_offset=0,
#      axis_line_join='miter',
#      axis_line_width={'value': 1},
#      bounds='auto',
#      fixed_location=None,
#      formatter=bokeh.models.formatters.LogTickFormatter(
#          id='f8cce1ac-4e00-4d23-a30b-cd3ec062c4f9',
#          js_event_callbacks={},
#          js_property_callbacks={},
#          name=None,
# ...

# %%
from bokeh.models import ColumnDataSource
source = ColumnDataSource(dict(
    x=nba.loc[2018].PTS,
    y=nba.loc[2018].W,
    team=nba.loc[2018].TEAM
))

# %%
source.data['team']
# Out:
# YEAR
# 2018           Toronto Raptors
# 2018           Milwaukee Bucks
# 2018               LA Clippers
# 2018     Golden State Warriors
# 2018            Denver Nuggets
# 2018        Philadelphia 76ers
# 2018     Oklahoma City Thunder
# 2018            Indiana Pacers
# 2018           Detroit Pistons
# 2018         Memphis Grizzlies
# 2018    Portland Trail Blazers
# 2018        Los Angeles Lakers
# 2018            Boston Celtics
# 2018         Charlotte Hornets
# 2018          Dallas Mavericks
# 2018          Sacramento Kings
# 2018         San Antonio Spurs
# 2018    Minnesota Timberwolves
# 2018      New Orleans Pelicans
# 2018             Orlando Magic
# 2018           Houston Rockets
# 2018                 Utah Jazz
# 2018        Washington Wizards
# 2018             Brooklyn Nets
# 2018                Miami Heat
# 2018           New York Knicks
# 2018             Atlanta Hawks
# 2018             Chicago Bulls
# 2018       Cleveland Cavaliers
# 2018              Phoenix Suns
# ...

# %%
PLOT_OPTS = dict(
    height=200, x_axis_type='log',
    y_range=(0,20)
)

# %%
from bokeh.models import HoverTool

# %%
hover = HoverTool(tooltips='@team', show_arrow=False)
p = figure(tools=[hover], **PLOT_OPTS)
p.circle(x='x', y='y',source=source)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c34c02c1-8b7b-4dde-ac14-5aae8513a47e"></div>
# </div>

# %%
from bokeh.models import ColumnDataSource

source = ColumnDataSource(dict(
    x=nba.loc[2018].PTS,
    y=nba.loc[2018].W,
    team=nba.loc[2018].TEAM,
    AST=nba.loc[2018].AST,
    OREB=nba.loc[2018].OREB
    
))
source.column_names
# Out:
# ['x', 'y', 'team', 'AST', 'OREB']

# %%
from bokeh.models import LinearInterpolator, CategoricalColorMapper

size_mapper = LinearInterpolator(
    x=[nba.AST.min(), nba.AST.max()],
    y=[0,30]
)
color_mapper = CategoricalColorMapper(
    factors=list(nba.TEAM.unique())
    palette
)

p = figure(
    title=str(2018),
    tools=[HoverTool(tooltips='@team', show_arrow=False)], **PLOT_OPTS)
p.circle(
    x='x', y='y',
    size={'field': 'AST', 'transform': size_mapper},
    alpha=0.6, 
    source=source)
show(p)
# Out:
#   File "<ipython-input-151-4829b7653da0>", line 11
#     palette
#           ^
# SyntaxError: invalid syntax

# %%
list(nba.TEAM.unique())
# Out:
# ['Toronto Raptors',
#  'Milwaukee Bucks',
#  'LA Clippers',
#  'Golden State Warriors',
#  'Denver Nuggets',
#  'Philadelphia 76ers',
#  'Oklahoma City Thunder',
#  'Indiana Pacers',
#  'Detroit Pistons',
#  'Memphis Grizzlies',
#  'Portland Trail Blazers',
#  'Los Angeles Lakers',
#  'Boston Celtics',
#  'Charlotte Hornets',
#  'Dallas Mavericks',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Minnesota Timberwolves',
#  'New Orleans Pelicans',
#  'Orlando Magic',
#  'Houston Rockets',
#  'Utah Jazz',
#  'Washington Wizards',
#  'Brooklyn Nets',
#  'Miami Heat',
#  'New York Knicks',
#  'Atlanta Hawks',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Phoenix Suns']

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-158-88a165568c10> in <module>()
# ----> 1 from bokeh.palettes import Spectral20
#       2 Spectral20
#
# ImportError: cannot import name 'Spectral20'
